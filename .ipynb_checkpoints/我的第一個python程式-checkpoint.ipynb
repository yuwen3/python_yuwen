# %%
1+1
# Out:
# 2

# %%
2**3
# Out:
# 8

# %%
4**(1/2)
# Out:
# 2.0

# %%
(22.35)*5/ 20
# Out:
# 5.5875

# %%
a =(22+35)*5/ 20

# %%
a
# Out:
# 14.25

# %%
b =5648965235263851685634513651345415324135666145141456456

# %%
b
# Out:
# 5648965235263851685634513651345415324135666145141456456

# %%
b+55
# Out:
# 5648965235263851685634513651345415324135666145141456511

# %%
b+21
# Out:
# 5648965235263851685634513651345415324135666145141456477

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([5, -5, 3, 8, -2])

# %% [markdown]
# 1+1

# %%
X=[0, 1.1, 2.5, 3.2, 4.8]
Y=[2.1, 3.4, 1, 5, 7]

# %%
plt.plot(X,Y)

# %%
plt.plot([X,Y])
# Out:
# [<matplotlib.lines.Line2D at 0x1ec7b2e0588>,
#  <matplotlib.lines.Line2D at 0x1ec7b2e06d8>,
#  <matplotlib.lines.Line2D at 0x1ec7b2e0828>,
#  <matplotlib.lines.Line2D at 0x1ec7b2e0978>,
#  <matplotlib.lines.Line2D at 0x1ec7b2e0ac8>]

# %%
np.random.rand(5)
# Out:
# array([0.11480023, 0.44433132, 0.47794114, 0.97805883, 0.08368798])

# %%
np.random.randn(10)
# Out:
# array([-0.39624632,  1.24166503,  0.68135145, -1.09276385, -0.56736595,
#        -0.87424242,  0.23361357,  0.74439943, -1.23016857, -0.11480253])

# %%
plt.plot(np.random.randn(10))

# %%
plt.scatter(X,Y)

# %%
X=np.random.randn(100)
Y=np.random.randn(100)

# %%
plt.scatter(X,Y)

# %%
x=np.linspace(-10, 10, 500)

# %%
y=x**2+1

# %%
plt.plot(x,y)

# %%
X=np.linspace(0,10,10000)

# %%
Y=np.sin(X)

# %%
plt.plot(X,Y)

# %%
plt.xkcd()

# %%
plt.plot(X,Y)
